# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data=pd.read_csv('/home/rgukt/Desktop/hiiiii/Application_Data.csv')
print(data.columns)
data.shape
data
# Out:
# Index(['Applicant_ID', 'Applicant_Gender', 'Owned_Car', 'Owned_Realty',
#        'Total_Children', 'Total_Income', 'Income_Type', 'Education_Type',
#        'Family_Status', 'Housing_Type', 'Owned_Mobile_Phone',
#        'Owned_Work_Phone', 'Owned_Phone', 'Owned_Email', 'Job_Title',
#        'Total_Family_Members', 'Applicant_Age', 'Years_of_Working',
#        'Total_Bad_Debt', 'Total_Good_Debt', 'Status'],
#       dtype='object')
#        Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children
# 0           5008806          M                1             1               0  \
# 1           5008808          F                0             1               0
# 2           5008809          F                0             1               0
# 3           5008810          F                0             1               0
# 4           5008811          F                0             1               0
# ...             ...              ...        ...           ...             ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
f,(ax_box,ax_hist)=plt.subplots(2,sharex=True,gridspec_kw={"height_ratios":(0.2,0.5)})
sns.boxplot(data['Applicant_Age'],ax=ax_box)
sns.distplot(data['Applicant_Age'],ax=ax_hist)
plt.show()
# Out:
# /tmp/ipykernel_53827/1987991776.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Applicant_Age'],ax=ax_hist)

# %%
f,(ax_box,ax_hist)=plt.subplots(2,sharex=True,gridspec_kw={"height_ratios":(0.2,0.5)})
sns.boxplot(data['Total_Children'],ax=ax_box)
sns.distplot(data['Total_Children'],ax=ax_hist)
plt.show()
# Out:
# /tmp/ipykernel_53827/1222706150.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total_Children'],ax=ax_hist)

# %%
f,(ax_box,ax_hist)=plt.subplots(2,sharex=True, gridspec_kw={"height_ratios":(0.2,0.5)})
sns.boxplot(data['Total_Family_Members'],ax=ax_box)
sns.distplot(data['Total_Family_Members'],ax=ax_hist)
plt.show()
# Out:
# /tmp/ipykernel_53827/3437256634.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total_Family_Members'],ax=ax_hist)

# %%
f,(ax_box,ax_hist)=plt.subplots(2,sharex=True,gridspec_kw={"height_ratios":(0.2,0.5)})
sns.boxplot(data['Total_Income'],ax=ax_box)
sns.distplot(data['Total_Income'],ax=ax_hist)
plt.show()
# Out:
# /tmp/ipykernel_53827/3992581095.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total_Income'],ax=ax_hist)

# %%
import seaborn as sns
sns.countplot(x='Applicant_Gender',data=data)
# Out:
# <Axes: xlabel='Applicant_Gender', ylabel='count'>

# %%
import seaborn as sns
sns.countplot(x='Income_Type',data=data)
# Out:
# <Axes: xlabel='Income_Type', ylabel='count'>

# %%
sns.relplot(x='Total_Family_Members',y='Years_of_Working',data=data,hue='Owned_Email')
plt.show()

# %%
sns.relplot(x='Applicant_ID',y='Total_Income',data=data,hue='Owned_Email')
plt.show()

# %%
import seaborn as sns
sns.histplot(x="Total_Income",data=data,hue="Applicant_Gender",multiple="stack",kde=True,bins=5)
plt.grid()

# %%
features=["Total_Family_Members","Applicant_Age"]
data[features].hist(figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'Total_Family_Members'}>,
#         <Axes: title={'center': 'Applicant_Age'}>]], dtype=object)

# %%
features=["Total_Bad_Debt","Total_Good_Debt"]
data[features].hist(figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'Total_Bad_Debt'}>,
#         <Axes: title={'center': 'Total_Good_Debt'}>]], dtype=object)

# %%
features=["Applicant_ID","Applicant_Gender"]
data[features].hist(figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'Applicant_ID'}>]], dtype=object)

# %%
data.columns = data.columns.str.lower()
data.isnull().sum()
# Out:
# applicant_id            0
# applicant_gender        0
# owned_car               0
# owned_realty            0
# total_children          0
# total_income            0
# income_type             0
# education_type          0
# family_status           0
# housing_type            0
# owned_mobile_phone      0
# owned_work_phone        0
# owned_phone             0
# owned_email             0
# job_title               0
# total_family_members    0
# applicant_age           0
# years_of_working        0
# total_bad_debt          0
# total_good_debt         0
# status                  0
# dtype: int64

# %%
# data1=data.drop('occupation_type',axis=1)
data.columns
# print(data1.shape)
# Out:
# Index(['applicant_id', 'applicant_gender', 'owned_car', 'owned_realty',
#        'total_children', 'total_income', 'income_type', 'education_type',
#        'family_status', 'housing_type', 'owned_mobile_phone',
#        'owned_work_phone', 'owned_phone', 'owned_email', 'job_title',
#        'total_family_members', 'applicant_age', 'years_of_working',
#        'total_bad_debt', 'total_good_debt', 'status'],
#       dtype='object')

# %%
data.dropna(inplace=True)
data.shape
# Out:
# (25128, 21)

# %%
for column in data.columns:
    unique_values = data[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print()
# Out:
# Unique values in column 'applicant_id':
# [5008806 5008808 5008809 ... 5150484 5150485 5150487]
#
# Unique values in column 'applicant_gender':
# ['M      ' 'F      ']
#
# Unique values in column 'owned_car':
# [1 0]
#
# Unique values in column 'owned_realty':
# [1 0]
#
# Unique values in column 'total_children':
# [0 3 1 2 4 5]
#
# Unique values in column 'total_income':
# [ 112500  270000  135000  130500  157500  405000  211500  360000  126000
#   247500  297000  166500  225000  315000  148500  202500  450000  180000
#    90000  765000  229500  292500   74250  144000  337500  193500  267750
#   139500   67500  252000  900000  279000   76500  234000   81000  108000
#   198000  216000   45000  238500  117000 1350000   99000  445500  427500
#   306000  328500  310500  540000  171000  675000  121500   72000  184500
#   189000  243000   94500  256500  697500  196650   40500  432000  162000
#   103500  257625   58500  207000  720000  261000  175500  382500  119250
# ...

# %%
columns_to_encode = ['total_children','income_type', 'education_type', 'family_status','housing_type','job_title']

# Perform one-hot encoding using get_dummies()
data1 = pd.get_dummies(data, columns=columns_to_encode)
data1
# Out:
#        applicant_id applicant_gender  owned_car  owned_realty  total_income  \
# 0           5008806          M                1             1        112500
# 1           5008808          F                0             1        270000
# 2           5008809          F                0             1        270000
# 3           5008810          F                0             1        270000
# 4           5008811          F                0             1        270000
# ...             ...              ...        ...           ...           ...
# 25123       5150482          F                1             1        157500
# 25124       5150483          F                1             1        157500
# 25125       5150484          F                1             1        157500
# 25126       5150485          F                1             1        157500
# 25127       5150487          M                1             0        202500
#
# ...

# %%
label_encoder = LabelEncoder()
columns_to_encode = ['applicant_gender']
for column in columns_to_encode:
    data[column] = label_encoder.fit_transform(data[column])
data
# Out:
#        applicant_id  applicant_gender  owned_car  owned_realty  \
# 0           5008806                 1          1             1
# 1           5008808                 0          0             1
# 2           5008809                 0          0             1
# 3           5008810                 0          0             1
# 4           5008811                 0          0             1
# ...             ...               ...        ...           ...
# 25123       5150482                 0          1             1
# 25124       5150483                 0          1             1
# 25125       5150484                 0          1             1
# 25126       5150485                 0          1             1
# 25127       5150487                 1          1             0
#
#        total_children  total_income  \
# 0                   0        112500
# 1                   0        270000
# 2                   0        270000
# 3                   0        270000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))
coor_mat=data.corr()
sns.heatmap(coor_mat,annot=True,cmap='RdYlGn')
print(data.columns)
# Out:
# /tmp/ipykernel_8334/1795889042.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   coor_mat=data.corr()
# Index(['applicant_id', 'applicant_gender', 'owned_car', 'owned_realty',
#        'total_children', 'total_income', 'income_type', 'education_type',
#        'family_status', 'housing_type', 'owned_mobile_phone',
#        'owned_work_phone', 'owned_phone', 'owned_email', 'job_title',
#        'total_family_members', 'applicant_age', 'years_of_working',
#        'total_bad_debt', 'total_good_debt', 'status'],
#       dtype='object')

# %% [markdown]
# # spliting the data set into testing and training data sets

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

features = ['total_family_members','total_children','total_bad_debt','applicant_age','owned_car','applicant_gender'] # Replace with your actual feature column names
target = 'status' 

X_train, X_test, y_train, y_test = train_test_split(data[features], data[target], test_size=0.2, random_state=42)

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score



lr_model = LogisticRegression()


lr_model.fit(X_train, y_train)


y_pred_lr = model.predict(X_test)
result_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr})
print(result_df)
# Out:
#        Actual  Predicted
# 13396       1          1
# 5324        1          1
# 13640       1          1
# 5070        1          1
# 17645       1          1
# ...       ...        ...
# 14085       1          1
# 9068        1          1
# 21692       1          1
# 2826        1          1
# 24534       1          1
#
# [5026 rows x 2 columns]

# %%
lr_accuracy = accuracy_score(y_test, y_pred_lr)
print("Accuracy:", lr_accuracy)
# Out:
# Accuracy: 0.9954237962594509

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier()

knn_model.fit(X_train,y_train)

y_pred_knn=knn_model.predict(X_test)

result_df2=pd.DataFrame({'Actual':y_test,'predict':y_pred_knn})

print(result_df2)
# Out:
#        Actual  predict
# 13396       1        1
# 5324        1        1
# 13640       1        1
# 5070        1        1
# 17645       1        1
# ...       ...      ...
# 14085       1        1
# 9068        1        1
# 21692       1        1
# 2826        1        1
# 24534       1        1
#
# [5026 rows x 2 columns]

# %%
accuracy2=accuracy_score(y_test,y_pred_knn)
print(accuracy2)
# Out:
# 0.9954237962594509

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
svm_model=SVC()

svm_model.fit(X_train,y_train)

y_pred_svm=svm_model.predict(X_test)

resultdf3=pd.DataFrame({'Actual':y_test,'predicted':y_pred_svm})
print(resultdf3)
# Out:
#        Actual  predicted
# 13396       1          1
# 5324        1          1
# 13640       1          1
# 5070        1          1
# 17645       1          1
# ...       ...        ...
# 14085       1          1
# 9068        1          1
# 21692       1          1
# 2826        1          1
# 24534       1          1
#
# [5026 rows x 2 columns]

# %%
accuracy_svm=accuracy_score(y_test,y_pred_svm)
print(accuracy_svm)
# Out:
# 0.9952248308794269
